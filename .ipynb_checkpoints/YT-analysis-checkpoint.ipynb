# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = "AIzaSyBHHudF-foivoHsAdZnUOwyXtQaJj522NE"
channel_ids = ["UC0T6MVd3wQDB5ICAe45OxaQ",
            "UC4JX40jDee_tINbkjycV4Sg",
            "UC8butISFwT-Wl7EV0hUK0BQ",
              "UCV7cZwHMX_0vk8DSYrS7GCg"
             ]

youtube =  build('youtube' , 'v3' , developerKey = api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id= ','.join(channel_ids)
    )
    response = request.execute()
    all_data=[]
    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]["snippet"]["title"],
                  Subscribers = response['items'][i]['statistics']['subscriberCount'],
                   Views = response['items'][i]['statistics']['viewCount'],
                   Total_videos = response['items'][i]['statistics']['videoCount'],
                   Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_statistics
# Out:
# [{'channel_name': 'freeCodeCamp.org',
#   'Subscribers': '9220000',
#   'Views': '680083906',
#   'Total_videos': '1610',
#   'Playlist_id': 'UU8butISFwT-Wl7EV0hUK0BQ'},
#  {'channel_name': 'Learn Coding',
#   'Subscribers': '1990000',
#   'Views': '191692837',
#   'Total_videos': '850',
#   'Playlist_id': 'UUV7cZwHMX_0vk8DSYrS7GCg'},
#  {'channel_name': 'WsCube Tech',
#   'Subscribers': '3230000',
#   'Views': '267575108',
#   'Total_videos': '5116',
#   'Playlist_id': 'UU0T6MVd3wQDB5ICAe45OxaQ'},
#  {'channel_name': 'Tech With Tim',
#   'Subscribers': '1460000',
#   'Views': '138216289',
#   'Total_videos': '976',
#   'Playlist_id': 'UU4JX40jDee_tINbkjycV4Sg'}]

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#        channel_name Subscribers      Views Total_videos  \
# 0  freeCodeCamp.org     9220000  680083906         1610
# 1      Learn Coding     1990000  191692837          850
# 2       WsCube Tech     3230000  267575108         5116
# 3     Tech With Tim     1460000  138216289          976
#
#                 Playlist_id
# 0  UU8butISFwT-Wl7EV0hUK0BQ
# 1  UUV7cZwHMX_0vk8DSYrS7GCg
# 2  UU0T6MVd3wQDB5ICAe45OxaQ
# 3  UU4JX40jDee_tINbkjycV4Sg

# %%
channel_data.dtypes
# Out:
# channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# Playlist_id     object
# dtype: object

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# Playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='channel_name', y='Subscribers', data = channel_data )

# %%
ax = sns.barplot(x='channel_name', y='Views', data = channel_data )

# %%
ax = sns.barplot(x='channel_name', y='Total_videos', data = channel_data )

# %% [markdown]
# ## function to get videos ids

# %%
channel_data
# Out:
#        channel_name  Subscribers      Views  Total_videos  \
# 0  freeCodeCamp.org      9220000  680083906          1610
# 1      Learn Coding      1990000  191692837           850
# 2       WsCube Tech      3230000  267575108          5116
# 3     Tech With Tim      1460000  138216289           976
#
#                 Playlist_id
# 0  UU8butISFwT-Wl7EV0hUK0BQ
# 1  UUV7cZwHMX_0vk8DSYrS7GCg
# 2  UU0T6MVd3wQDB5ICAe45OxaQ
# 3  UU4JX40jDee_tINbkjycV4Sg

# %%
playlist_id = channel_data.loc[channel_data['channel_name']=='Tech With Tim', 'Playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UU4JX40jDee_tINbkjycV4Sg'

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
           part ='contentDetails',
            playlistId = playlist_id,
        maxResults =50
    )
    response = request.execute()
    video_ids =[]
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                part ='contentDetails',
                playlistId = playlist_id,
                maxResults =50,
                pageToken = next_page_token)
        response = request.execute()
        for i in range(len(response['items'])):
            video_ids.append(response['items'][i]['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
            
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ['Y21OR1OPC9A',
#  '5mMpM8zK4pY',
#  'lSyGTNttrME',
#  'P4CRVTB2B5s',
#  'QkV3xlxdF_0',
#  't-uAgI-AUxc',
#  'lCLATD5vEBU',
#  'y_1-hOBcLas',
#  'PppslXOR7TA',
#  '-3bVuFcteUo',
#  'ul0QsodYct4',
#  't9CAFYn7YgY',
#  '2ml4x0rO1PQ',
#  'KYp2xWcRWYQ',
#  'zCEJurLGFRk',
#  'BYzRCxCEXiM',
#  'yTzqWczUrM0',
#  'NpmFbWO6HPU',
#  'HpK79yY5GPE',
#  'UwBOi_mUKHE',
#  'nrN3Gq1A92Y',
#  'AhBLgJxw53A',
#  'LO5eRF1FdkI',
#  'logFYVSgQnA',
#  'LOGuP81D8wc',
#  'Wanv3_LVqfs',
#  'eDIFT3aOexw',
#  '1Hyik2NWvkU',
#  'tE-8bG35VNw',
#  'A_Sfru99QNA',
#  'MxTBvsAqhxI',
#  'uO6r0vQmGB0',
#  'czxvoZ73SME',
#  '9MArYMVWubA',
#  'mrjq3lFz23s',
#  'VyM4wCuuPD4',
#  'V1hjSeSF4xg',
#  'zT7niRUOs9o',
#  'Yl3xCV2bN6E',
#  '7pfRiFB__k8',
#  'NB8OceGZGjA',
#  'ydOZ5YAv8Hk',
#  'IlS1aR_gfzs',
#  'P--Eaq2QjNQ',
#  'c8vd7ogxh7g',
#  's46yyTKvl-I',
#  'lVbElR_HwXQ',
#  '44en4a5fPZw',
#  '9KvBBZ7WLKI',
#  'HTfwhmHVpqM',
#  'bYYd_IlOb9k',
#  'q5HiD5PNuck',
#  'Z-7DRZT4DKA',
#  'YDKuknw9WGs',
#  'nhYcTh6vw9A',
#  'aOAyv2NAK1c',
#  'UR9C2DLHkHk',
#  'vYn-WJzBfcM',
#  'CAeWjoP525M',
#  'MM9ukNfvn2I',
#  'lwquHLH958w',
#  'A9C5l3AOOA0',
#  's4Aj1CXbLLw',
#  'o_UuZVvKtqY',
#  'f2b7hP4Qu1M',
#  'BaFdKJxWspk',
#  'YZ8-GmTT7uM',
#  'CzA4KMife28',
#  'w5KN-xuh3-I',
#  'nGIg40xs9e4',
#  'Uf5MYaWKTw0',
#  '3cUkvFKYbHE',
#  'U80grnZJm_8',
#  'qdWg8fv5Iz4',
#  'ZIw7QGVwaNI',
#  'MNMVaV4vJFM',
#  '21FnnGKSRZo',
#  'DJnH0jR8y5Q',
#  '8P0xNyFpqeg',
#  'VGK52xzA4fM',
#  's5r97DdKuKc',
#  'ZymXD46f7R4',
#  'WjEewydBiGk',
#  'bAyrRXFCVkk',
#  'VSl_503U4iw',
#  'whyQgRK4c8I',
#  'XVcRQ6T9RHo',
#  'L8fZD4I2C0g',
#  '7YIng9kZalI',
#  '21WFgScvrdg',
#  'LJmv_9EV7e8',
#  'RK9mfuFgm54',
#  'Liz-F0pY1Pw',
#  'niR4e1J_G40',
#  'CLrNPo0B68I',
#  'zsYIw6RXjfM',
#  'mMv6OSuitWw',
#  '96_fLPC8hOU',
#  'sZ0uYHnlAuk',
#  'ravzCiGpZ28',
#  'QAF1bg8KoK4',
#  'RRLYK3emhJg',
#  'IR8ql3wAXzg',
#  'MDb5vODM1r8',
#  'ncmMPbHD7uY',
#  'v6sI1tidSw8',
#  'gW92DcU1s-U',
#  'Gj02l0R1drM',
#  'eFhypUFY1Ws',
#  'yId3Hq-SIvo',
#  'C_teb93alL4',
#  'GjUcWNj6Zrc',
#  '3SoRlkMS2lQ',
#  '1OdKhKHHzcY',
#  'As6QAVuEqDY',
#  '_lMUYQ0PQ0U',
#  'UEOtZvTCmDo',
#  'KsVqK4JmY2c',
#  'JmhgkCk865o',
#  '2BX63Zgl43U',
#  'uaG-xp1X5LU',
#  'xnFGXXYhW_I',
#  '_AUcXe2kI7U',
#  '9zKDWiiHLmM',
#  'IAo4Q1IvJxA',
#  'cDeTUYkaEkg',
#  'Y_0ReCfEDck',
#  'zhUjpnTbgUE',
#  'BkIqDz_rmO8',
#  'JdI_b1StvpE',
#  '6sUDDsHVM90',
#  '6BVCdixuj5s',
#  '5E4DRWa1IEE',
#  '9s_TBv8tzGU',
#  'fFcc9OItJLM',
#  'VqO8vjh3VFI',
#  '6dsuowZVv6Q',
#  'p7AsUMDiXrs',
#  'SWd_KU70C0s',
#  'tDSh9ohiNe0',
#  '0E6O8r-UsuQ',
#  'ykkpSalKfIY',
#  '4C_hG3CI4IE',
#  '9v7b8gOIkjw',
#  'S9ehGRNLhH0',
#  'Hz-Kmxn0G4I',
#  '-WU3bLzmfXg',
#  '9fZwZob3lGA',
#  '7h6_aZZ_iNg',
#  '7ubBBIwAse8',
#  'JOqw_XArBDc',
#  '4Jn4fE1Z6rs',
#  '2zW5emKWof8',
#  'qTWiG1krM2k',
#  'FvXHE6CcEf4',
#  'FIpbrnbVfJk',
#  '2yf9tyq9usI',
#  'h1T5AKYelBs',
#  'qecsnAXtms4',
#  '-r-M5bW8W5A',
#  'iGJlrTI0H1Q',
#  'ObUoqDqj6ck',
#  'V7nL0cDnx24',
#  'waY3LfJhQLY',
#  'Gi0-Or2HVA8',
#  'EY8BvORuG_M',
#  'ZwCft4RSS_8',
#  '6znDOTzZkfw',
#  'E3XxeE7NF30',
#  'u2uYEMna-WU',
#  'cYIECS3E894',
#  'jU8g21HsoJY',
#  'mkXdvs8H7TA',
#  'qYD68F0yQSA',
#  'M5CPeGXcfgg',
#  'Ev752v9bOak',
#  'jO9_vlc1_L8',
#  'Iv8_Of5rt7o',
#  'dqNLP2uYcDU',
#  'phC-vKlNoaM',
#  'u1txg12Gxpk',
#  'a0peNsoHGdo',
#  'no5dz0GOWy8',
#  'kyrlXEHXyKs',
#  'cedufswLtZ8',
#  'XCIBOl3FTKo',
#  '1Zku-mXDY9g',
#  'hl8QKaXE_Vg',
#  'gT_g5eEuWDI',
#  '16QKPVsk-Qw',
#  'VyOQ6OMOYZI',
#  'SxZrtrWr6Ak',
#  'u2CqBt_EduQ',
#  'sP-gFDreaQ4',
#  '-scY8wDZpyY',
#  '91eHwE7fpzs',
#  '6NYSDSHBkuc',
#  'hneIC0f-pFg',
#  'TFIFkvGimDw',
#  '9NQRMBNGBt8',
#  'qqz04rpEW2k',
#  'eg2mRZ4gm_Y',
#  'p7cbzvd_Eso',
#  'vwBxc8qfei8',
#  'x22v39Cka1o',
#  'WRker6iTzE8',
#  'iGcEsLOyCL8',
#  'q1uNSkRH9Y8',
#  'o_m59nMWny4',
#  'pbP5bqfbUPk',
#  'qI3P7zMMsgY',
#  'qLI4y19f738',
#  'B6DrRN5z_uU',
#  'ZF2_JKNcDek',
#  'dQlw1Cdd3pw',
#  '_RfG-3twZbk',
#  'kMrvX6HrFoY',
#  'N6tzhlilNZY',
#  'BM9tPve8T1o',
#  'H1UKIgBSfxM',
#  'wsETdTd1rp8',
#  'wJNikDr-aNM',
#  '-V_q9MJDrZY',
#  'th4OBktqK1I',
#  'NYktbp1WFS8',
#  'Ss5WWolaOLY',
#  'lHhL2Cj1zSY',
#  'K-Ek0gT8JPM',
#  'vxctuiRlmrs',
#  'vHiklIWMZA8',
#  'ZzoAu4VPyho',
#  '8nIi2x2m6yE',
#  'Nulac4Q15Io',
#  'CQv7wfZIcs0',
#  'NvBoFER9Y1Y',
#  'FHTL9q9BucM',
#  'u3YoNpSnmis',
#  'BPknKs2XAQs',
#  'GYugz6LxfhE',
#  'MPBCiSnAm9E',
#  '-6cnnNlAvNk',
#  'APrANyLHCtQ',
#  'RPrBGrQsIek',
#  'MOa7ulhNYc0',
#  'eYjWLdLgKqg',
#  'X6hbdFv8Q3c',
#  'Uwa3P9dBHdA',
#  '7qH8prh4hpE',
#  'PQBX-ev5q2k',
#  't047Hseyj_k',
#  'xYgfW8cIbMA',
#  'svJ0FtfyfRo',
#  'gvgBUY8iNO4',
#  'T_KrYLW4jw8',
#  'nc-Kpiq1zLc',
#  'nYNAH8K_UhI',
#  'UpsZDGutpZc',
#  'urrfJgHwIJA',
#  '-6_GJ0yrbrU',
#  'D2UP8MRbmVg',
#  'vX-1ZT-y1m0',
#  'COsG94dExUI',
#  'Wx-gL-Dt5rI',
#  'sXE5298aDPw',
#  'RRYgc4YIhEs',
#  'KFwFDZpEzXY',
#  'p8FUoSIyIVY',
#  'WuyKxdLcw3w',
#  'txKBWtvV99Y',
#  '4XLdWcgygMQ',
#  'eWhHqrjhe_A',
#  'kP653WDJcdg',
#  'PlWPH_VUlNE',
#  'tLsi2DeUsak',
#  'Sz9yH-RDAgo',
#  'e9yMYdnSlUA',
#  'iRORiaLAgaE',
#  '2f6TmKm7yx0',
#  'WTLPmUHTPqo',
#  '6aDHWSNKlVw',
#  'vVGTZlnnX3U',
#  'cv_EiyPlFpY',
#  'x5FHbr0Em5A',
#  'v68woFABJ5U',
#  'ZiwvZenOzto',
#  'REj6fj7AxbI',
#  'bj77B59nkTQ',
#  '-51jxlQaxyA',
#  'Oz3W-LKfafE',
#  'SZuwBPHKBEE',
#  'V1PdbnuPMi8',
#  'zbmcAtR8CAo',
#  'yZO5Mnr7hl8',
#  't_vTQEQVCkQ',
#  'zwC2FQcSpK4',
#  'EsjfV_9qY6g',
#  '8kEBwJt2YLM',
#  'DOIPzJQmjfE',
#  'twRidO-_vqQ',
#  'QV3d6yN_HM8',
#  'cZs6kh0WFRY',
#  'VMMmGzgvNfw',
#  'LEe1IxA2h_I',
#  'LHhsNa_Kgns',
#  'XQrNtTSQyAU',
#  '7iFT6_x5azc',
#  'elfqLbiLAT4',
#  'H-DCpFRQ2dY',
#  'VzhZ1nTeAsA',
#  'NNeT-PhaLZk',
#  'JBE4OwdqzQ8',
#  'Db4oc8qc9RU',
#  'NQ5i1kJAA6Y',
#  '-H7PXerOgiY',
#  'NBuED2PivbY',
#  'dfCDmsBZIjI',
#  '19r7FO6kaXA',
#  'l2X5rwJ_bW4',
#  'nNHecqChuKk',
#  '4hSMpvs5r04',
#  '19E9RQC5kDo',
#  'knH_woIJ6-o',
#  'wTXDQUzWF8o',
#  'TDf3MdW2_hU',
#  'agnVylvZ038',
#  'ZnkV6ST4a_U',
#  'V_B5ZCli-rA',
#  'tmO79BvNMBY',
#  'WfqXcyF0_b0',
#  'rBamvYwO3gg',
#  '_tBHdKsRLVM',
#  'L3ktUWfAMPg',
#  'DiQe_rowIuA',
#  '6igd8-2woeE',
#  'sSW32VaBbNA',
#  'L9pw3kbc4KI',
#  '8__v2c588v4',
#  'QORvB-_mbZ0',
#  'h5YiHNh8S5Y',
#  'NgIWu-lDucM',
#  'Exic9E5rNok',
#  'Nm8NF9i9vsQ',
#  'haxotc0xq48',
#  'C64HXRU3GuQ',
#  'kng-mJJby8g',
#  'lUrWJVCCVGc',
#  'zAEfWiC_KBU',
#  'lC6mucyD17k',
#  'lOzyQgv71_4',
#  'gRLHr664tXA',
#  'lfQvPHGtu6Q',
#  '5Ui37whUDrM',
#  'ObkjC2j6Zko',
#  'D4_s3q038I0',
#  'Jj2T4TuHRRo',
#  'PeJNU339WHc',
#  'hz7ipeH5Dug',
#  'tMNJtYDSOBY',
#  '1N6VBHMoPsw',
#  'IOy7DVkG-og',
#  'u3T7hmLthUU',
#  'M_OKJnIdYeU',
#  'CssrFJGH_dU',
#  'f_bml-MILAs',
#  'W4GItcW7W-U',
#  'GQcM8wdduLI',
#  'e_kogQ1r9u0',
#  'FyHjghBHgRg',
#  'B_1Qah25EyE',
#  'N20eXcfyQ_4',
#  'F14BKKHeAKU',
#  'ScUKeVuL7Y8',
#  'jQXtpwsWRas',
#  'zx8umUkWKNY',
#  'OJk5rD7st-I',
#  '_ABdBoW4DV8',
#  'jjxkevSOfXY',
#  'ohAWWurYZ18',
#  'zqncrdTDVbI',
#  'k67TMBC6tyo',
#  '4IkzPbVUZVc',
#  'gtkL4sGkQj0',
#  'AO6urf07KjE',
#  'EOYag-8ipXE',
#  'DLn3jOsNRVE',
#  'e97K1xj9CUg',
#  'lO6MunNmZWU',
#  'vMeR1aaNhtk',
#  'qnyfvN4CIbo',
#  'JtB_tippTUQ',
#  '-ykeT6kk4bk',
#  '8e4Ze_xX8e0',
#  'Ma6DRDIedVE',
#  'YOxaIHGg0hM',
#  'C83tPpvxIJA',
#  'wS058nq0APU',
#  '7YS6YDQKFh0',
#  '682xT_TcKUg',
#  'RXzzE2wnnlo',
#  'Pg_jNuq9s9M',
#  '7mwgA9XFIEQ',
#  'T9-agjKW4PQ',
#  'jUbOcBkdMF0',
#  'q7AX76ExOFw',
#  'RGYGiLUAQ3c',
#  'YETgGK8Dnss',
#  'Oo6eOIUDA2A',
#  'QtP0PdLEvFk',
#  'XQzEo1qag4A',
#  'uOlLs1OYSSI',
#  '0MKFrY6jSkk',
#  'jG4Vs81kMlc',
#  'aOskrzlcBRY',
#  'gVmTVsAn6EI',
#  't5Bo1Je9EmE',
#  '1FVBeLD_FdE',
#  'Zkr0aAdD1Ww',
#  'gQP0geNsO4A',
#  'F__aAx-3HOY',
#  'bOLNq4tkwj8',
#  'KVFF-HTYbXM',
#  'sm1mokevMWk',
#  'BOnHRS9cpSo',
#  'taBgBbXRadc',
#  'jLDDUehyCBc',
#  'CWtiqVQp8uk',
#  '6iwIZ0ND-40',
#  'EKAx918CP5g',
#  'OA28SYILJv8',
#  'zgutFVxOlTY',
#  'ckbfOdMhZls',
#  'SFgEPbmeJOk',
#  'lPd13fsU-CQ',
#  'KYNbHGs-qG4',
#  'u9ZqynGOXl8',
#  'mPCZLOVTEc4',
#  'X1l1fbkHQqw',
#  'yMKHmbxQWMY',
#  'T-0lZWYWE9Y',
#  'I7lCpTOfxF4',
#  '4iiw3yx7pTk',
#  'ddSo8Nb0mTw',
#  'bPSfyK_DJAg',
#  'rKcwcARdg9M',
#  'ORrELERGIHs',
#  'wlYPhdTbRmk',
#  'qCR2Weh64h4',
#  '7N3fQBuve3Y',
#  'dam0GPOAvVI',
#  'HvjYxuU6LHk',
#  'dp-D9HNuVcM',
#  'fDaPYJwuS6M',
#  'paQQ5HCpaRc',
#  'ml9-HpyMnaU',
#  'XPZSkEagn68',
#  'e_aZAIv76fg',
#  'sDpyK4OnbBc',
#  'GsWoaxJJPbs',
#  'QkP9vyVGbbk',
#  'gQTrYcH0b7g',
#  '5rhX7PepzaU',
#  'ebHX9c75H8I',
#  'OZ1-BvmHHjE',
#  'jO6qQDNa2UY',
#  'qXFGBUcZ5LU',
#  'UEuXQjPUwcw',
#  'Lsq9oRZ2WiU',
#  'WvbU4B5hBFE',
#  'yrqyol4B1RU',
#  'R-22NeS-P2c',
#  'rYDDWVuv-kI',
#  '9aHMQ3Zcorc',
#  'u51Zjlnui4Y',
#  'Yv_4RXyLjL8',
#  'YDgZd9i3le4',
#  'xqyhOFlA8pw',
#  'JOpmlhAZsPI',
#  'HMdZmxb8WIk',
#  'uhyHwY94vwQ',
#  'ZP8ZMlKjT4o',
#  '2i6FeATm9ZY',
#  'qpyUSAur8g0',
#  'H9rHrlNTpq8',
#  'bQXhG1eZGLM',
#  'mAy-J5TrdPU',
#  'k6ELzQgPHMM',
#  'JacxrQVfLGw',
#  'llek2ZmcVpE',
#  'YEmjBEDyVSY',
#  '6c2NqDyxppU',
#  'uhSmgR1hEwg',
#  'JD-age0BPVo',
#  '5gxSHuscNS8',
#  'Hnlr9H0kCHE',
#  'uhOxwIZwV1g',
#  'O0WwgAnFSCc',
#  'yHT0TOOMD5s',
#  'sEFx0b9y_Xo',
#  '6gHvqXrfjuo',
#  'KJ5bFv-IRFM',
#  'aPvHcc0ysm0',
#  'LIYGIM7Qd9M',
#  'kbwk1Tw3OhE',
#  'rd6SgAIvGjw',
#  'VchuKL44s6E',
#  'rzcZLZTwmf8',
#  'Ye5JbYV1q-0',
#  'mYbrH1Cl3nw',
#  'RjdrFHEgV2o',
#  'Nl5KqXasBx4',
#  'bASNF0uqivM',
#  'lv4rmBDlSE8',
#  'rZurceHOIJQ',
#  'mL6qLYCstTM',
#  'yZxQdTK8UGE',
#  '_kOXGzkbnps',
#  'LSYj8GZMjWY',
#  'vnd3RfeG3NM',
#  'F5kPAZZ-CNE',
#  'eLOj3BHrZZs',
#  'p15xzjzR9j0',
#  'MvhAOfKT58A',
#  'qWjnxjB-sTA',
#  'VuMJ0fDj4mM',
#  'a78Qc8rpO7c',
#  'LeTgMYlGVrM',
#  'eCcY_SDEId8',
#  '35BFOsQ_tZw',
#  'VHK8VrTFk4c',
#  'KDCoqqQN_vM',
#  'HUtHp3duGbI',
#  'mXREh3S8Yw0',
#  'jNDsTI-poYo',
#  'aqtCU7Nk9h4',
#  'ly0hAtV7EBg',
#  'JtiK0DOeI4A',
#  '6thjSbJcoUc',
#  'GMppyAPbLYk',
#  'eqrKxDbzhbg',
#  '7qZBwhSlfOo',
#  'dXY7Tol4sRI',
#  'FLtqAi7WNBY',
#  'd038LZp_Jhk',
#  'W6cjx7t39d4',
#  'L9nCPdIXneI',
#  'UEO1B_llDnc',
#  'DVRQoVRzMIY',
#  'GaLOniEq7Ys',
#  'lmiM8Oaw09w',
#  '1NKGJI_r1e8',
#  'ie36e_mk_sQ',
#  'LEXFAgBBfE0',
#  'lh_Uv2imp14',
#  'lUWkxFEfe2g',
#  '5b8MMXgBnp0',
#  'dm9oXt6_YNA',
#  '7R-CfL21zIY',
#  'a4HcEsJ1hIE',
#  'vtYTl4pNDSI',
#  '8Stfdfcdt0E',
#  'vdm04bVzkLg',
#  'CrgD_otSzDI',
#  'i43W0XSiuIE',
#  'yJE2RC37BF4',
#  'DYqpu3jF2_4',
#  'KzKNGGoaT5U',
#  'e-oBn806Pzc',
#  'siOPdXdQImg',
#  'jZ-llP_yKNo',
#  'oij82Cp9K1A',
#  'QgBYnz6I7p4',
#  'QvPa8C0y9yc',
#  '63au_xLLp0A',
#  'qCtgLbFWPI4',
#  'r4TgqWbKRtA',
#  '1-bM3lSBDaA',
#  'GQ880MlHBBE',
#  'UVp7Cz1NMwA',
#  'AywUPZIv6lU',
#  'pM0-CMysa_M',
#  '75lJDVT1h0s',
#  '-6ikAMmu3Nc',
#  'gJY8D468Jv0',
#  'sxTmJE4k0ho',
#  'O_sIPPA4euw',
#  '9_5Wqgni_Xw',
#  'OISEEL5eBqg',
#  'U6gbGk5WPws',
#  'b5jt2bhSeXs',
#  'Xjv1sY630Uc',
#  'P1doPpgVLNs',
#  'aRAgOMG7Sss',
#  '6w3DSk94V2o',
#  'Q-__8Xw9KTM',
#  'x-7bntZ2cJ8',
#  'sbtbIqEG4nI',
#  '3QiPPX-KeSc',
#  '-njsRb8Tn70',
#  'JeznW_7DlB0',
#  'II7UCUbxOus',
#  'NtSX-UNLvlQ',
#  'Vi9Y9AL13Rc',
#  'cdPZ1pJACMI',
#  'olYdb0DdGtM',
#  'G-tuXeMyb58',
#  'Lv1treHIckI',
#  'eXinDi55iOk',
#  '2eiFCQ-YAf4',
#  'tfCz563ebsU',
#  'ckW4cUqui_w',
#  'yMhVCsXcItI',
#  'NAQEj-c2CI8',
#  'z11P9sojHuM',
#  'mclfteWlT2Q',
#  'MgkldDDFJF4',
#  'i824zN0DGIo',
#  'AigDGDA8NHk',
#  '8gNTyr1DXc4',
#  'IuiG3MUzcIE',
#  'SDGUhxZorF4',
#  '1cCai6JC_dQ',
#  'XdL2cESAYrs',
#  'Cxk5NBOBT7o',
#  'J_ud6KxX_s0',
#  'DCJVYbu0MUQ',
#  'l8QSG4rTnjg',
#  'QtLbuFUI1I4',
#  'iz2JoVLmXn0',
#  'XLIHPU_jxUY',
#  'uEKDSLwf2Gw',
#  '0W_loZstWMg',
#  'hEzkm9wuNbY',
#  'wGf4-6WraDE',
#  '0c8VLtIhQgs',
#  'pjJuqWWqEDI',
#  'eE-Spyy90qA',
#  'nnk-aHggi0Q',
#  'jl5yUEdekEM',
#  'xDY1TTM9sGs',
#  'rjLHje_SkE4',
#  'rcGQxs7STvk',
#  'JcKse_OhnfQ',
#  'M7oBYzBJeFY',
#  'Fk1ERg6xpAg',
#  'j6GdOEKA580',
#  'XWo3YUblZxk',
#  'SrSBhuuuIsg',
#  'ykoxwrm0Seo',
#  'TgCKJU3JvO4',
#  'Ou_hSDxzjMI',
#  'RNRmh9hMmtA',
#  'WFr2WgN9_xE',
#  'YFBRVJPhDGY',
#  'ew7kP57GzKA',
#  'WteIH6J9v64',
#  'tXpFERibRaU',
#  'KyGFVrcuMZM',
#  '1nxzOrLWiic',
#  'uZnp21fu8TQ',
#  'qbnqNWXf_tU',
#  'AEbmDrf8m-k',
#  'iIhAfX4iek0',
#  '9MHYHgh4jYc',
#  'x2IQP8iug3c',
#  '4nzI4RKwb5I',
#  'xIgPMguqyws',
#  'mqhxxeeTbu0',
#  '6Wz5yVDDU3Q',
#  'mlfO0FBb6eY',
#  'wDIQ17T3sRk',
#  'N3GH3ftUgNc',
#  'WltqUaqxBH8',
#  'f7oYCzKuv-w',
#  'kUBGiABFFHc',
#  '91iNR0eG8kE',
#  '3vsC05rxZ8c',
#  '4ethYataA2o',
#  'jjh_P5wg-ww',
#  'ALWe-tbrzQU',
#  'nl7kDPYD20A',
#  'dLVTBImEEXA',
#  'zkMy1j-0yh4',
#  'PoVnDZw3dDY',
#  'BOhgGA7Eu5E',
#  '9H707dLSlfg',
#  '0fq69_9iEqc',
#  '8iD91RzuHSc',
#  'a2cKbsCpD-o',
#  '-MZiQaNI0QA',
#  '9LrtOJTnwJE',
#  'MIqvaX_Q0c8',
#  'H9ZJ1uT8RFw',
#  'KQasIwElg3w',
#  'JrlVfhBXXDE',
#  'EyDkBP05eKc',
#  'rTbePMu_hVY',
#  'TsFd1qh9D6c',
#  'c3rNZ-GlQlw',
#  'l131g38hheM',
#  'zqEoTxkh95M',
#  '-AzGZ_CHzJk',
#  'edfGASf_QxE',
#  'o5sb8ehRSYA',
#  'NPbHUyVDYDw',
#  'wQWWzBHUJWM',
#  'MPFWsRjDmnU',
#  'SYqQ5oddgcw',
#  '1xkykD5Olok',
#  'ps55secj7iU',
#  'MMxFDaIOHsE',
#  '3RzC2NrCO24',
#  'gztwNv4o_9E',
#  'HB7TcYklBHY',
#  'OGHA-elMrxI',
#  'B2KusJcbVIg',
#  'EHff0DLktJs',
#  '1j2gWyY5CK4',
#  'K-HouEVT7q4',
#  '_K_QIx1KGuA',
#  '1HHRWg--Ce4',
#  'crJVzc5Ct_s',
#  'nHuHpVqtYOM',
#  'GkgMTyiLtWk',
#  'SR8xeaRXLcg',
#  'D0iCHFXHb_g',
#  'HYV81L7qd6M',
#  'FVpho_UiDAY',
#  '-2uyzAqefyE',
#  'Vde5SH8e1OQ',
#  '8T0XIQBeZwo',
#  'OXi4T58PwdM',
#  'RvbUqf3Tb1s',
#  'rE_bJl2GAY8',
#  'bWwZF_zVf00',
#  'D5xqcGk6LEc',
#  'nx8gDSS1vO4',
#  'Tw0mG4YtsZk',
#  '6Hau75Zkpj4',
#  'E9jV1otS8fA',
#  'jBXAi-Vm_-g',
#  'ICL7VRKvS_A',
#  'PzzHOvpqDYs',
#  'ON5pGUJDNow',
#  'wypVcNIH6D4',
#  'ejZqLsQDjuo',
#  'zTGrt1oyul4',
#  'Xmga_snTFBs',
#  'sGjkCIm10C4',
#  'IpYmz3_BUM0',
#  'qpb_39IjZA0',
#  'k-_pWoy2fb4',
#  'RqLD1INA_cQ',
#  'cvNtZqphr6A',
#  'wu9IH1Xvdd4',
#  'OS0Ddkle0o4',
#  'iLHAKXQBOoA',
#  'SyhQDQ5Q6Js',
#  'z4lfVsb_7MA',
#  'Ev5xgwndmfc',
#  'ZFZ10MF_uVo',
#  '0mCZdemSsbs',
#  '914JH3t64Kg',
#  '9jDEnSm4nt8',
#  'vM9mcWr1RMg',
#  'u1rCAKyuK6Y',
#  'zoQjMMa73WI',
#  'b0CgA_Ap_Mc',
#  'dTXyCGVmjL8',
#  'UxTwFMZ4r5k',
#  'Z4D3M-NSN58',
#  'PWqS4NBhEY8',
#  'rsiXfs0zCqQ',
#  '_Z9Mz2V-Mig',
#  'V-5d87ESdWg',
#  'lK4N8E6uNr4',
#  'eqUwSA0xI-s',
#  '6EM3hSJeTNU',
#  'goWkNKHXkMg',
#  'mWU7t6Wu9sM',
#  'XHPTq56U06Q',
#  'YJagw7GfZcE',
#  '_EXBRQxM8O0',
#  'SDAkQq17S2Q',
#  'CHS5cGrUWFs',
#  'GFfMuyNUnDs',
#  'cnPlKLEGR7E',
#  'J2wEhFfRRco',
#  'nfQIciZbrxE',
#  'VV31Z-H075M',
#  'Jr02fUyO5Qo',
#  'AKetBTpL-Xk',
#  'UIlO7TbwrBE',
#  'F257x_E6H4k',
#  'qbL4hPWcnFM',
#  '_whymdfq-R4',
#  '_fx7FQ3SP0U',
#  '53Fdn4Hh_J8',
#  '4twKNHypPN8',
#  'HvjsMrR51lg',
#  'mIB7IZFCE_k',
#  'hettiSrJjM4',
#  'QQlOCWEhmrM',
#  'PpLuyOzCKTQ',
#  'xaYn4XdieCs',
#  '8vD-V5jpjBo',
#  'yg7n8hP6k1w',
#  'lnOTAq4NQfQ',
#  'H8aWfu9aICc',
#  'AS3b70pLYEU',
#  'fGWHQA3LhJ8',
#  'QUHnJrFouv8',
#  'bMHK6NDVlCM',
#  'BPvg9bndP1U',
#  'RwAqp26s9aE',
#  'eFxrnBxpRE4',
#  'XjfxYfKFXO8',
#  'xdg39s4HSJQ',
#  'zixd-si9Q-o',
#  'g1Zbuk1gAfk',
#  'l2I8NycJMCY',
#  'JHxyrMgOUWI',
#  'dNBvQ38MlT8',
#  'TQKI0KE-JYY',
#  'vwLT6bZrHEE',
#  'ddqQUz9mZaM',
#  '3AQ_74xrch8',
#  '1BYu65vLKdA',
#  '45ryDIPHdGg',
#  'ujTCoH21GlA',
#  'x81mj8ANlHY',
#  'CjwVL8mED4I',
#  '5818gtPtPLM',
#  'm90goRUpWV0',
#  'A17rkOzKfow',
#  '9jtRaEbqt-E',
#  'K7uvUtGPcYs',
#  'tORoVluMDps',
#  'LkhhyJM3RRI',
#  '-3B1v-K1oXE',
#  '1b-R6TxZMEk',
#  'YFPVyj_aP64',
#  'LRHvRJw_Djk',
#  'WiprCVc7lDY',
#  'v6mkj9H629Q',
#  '1BAZsQBteDs',
#  '_Wf2rbL9wQU',
#  'CFvTlTcZBTY',
#  'ojYxKBoZ44c',
#  'jcHk4ilAbPY',
#  'ZtcX0OXXRWk',
#  'ofKz3XGv6ZQ',
#  'RPoquiZydYc',
#  'DEcFCn2ubSg',
#  'P8FmdbRxX34',
#  'B8dOAW3tO_8',
#  'KZFn0dvPZUQ',
#  'cdfuuyXzuyc',
#  'ZfG6yyLvTRE',
#  'xY__sjI5yVU',
#  'MpuOuZKWUWw',
#  '39m3rstTN8w',
#  'H2SQrZK2nvM',
#  'jQiUOV15IRI',
#  '6fl3qCJhk8o',
#  'v_Jp11xqCzg',
#  'HRKQlEfEMCA',
#  'hPnZqWSRNZI',
#  'jNW97izstLg',
#  'VgBnkkPlEVI',
#  'e4azJxICkR4',
#  'UZX5kH72Yx4',
#  'HcGQB1nHOOM',
#  'W8xCUu_zlQs',
#  'uoR4ilCWwKA',
#  '1E3UlFvPMIU',
#  'xd035BdDQLg',
#  '_aDhWBk1ssI',
#  'rfvc66Qog4o',
#  'sRGpvbhOhQs',
#  '56bPIGf4us0',
#  'Jt0fNgJr400',
#  'J9RQcF7hhgA',
#  '2pCxRTu5SHc',
#  'huJhs_5ifzs',
#  'Qgh1vjmaj44',
#  'biLz7KPgHJA',
#  'gXhvxf-1FBM',
#  '_Uq4RXtMRiU',
#  '3RGeoVQfm7g',
#  '5tvER0MT14s',
#  'm3JgSV1Obn8',
#  'GKgpvriuQY8',
#  'cgDRugJzBfM',
#  '9XQOd8ODNbs',
#  'BcbVe1r2CYc',
#  '09XRMXcCofM',
#  'H1FD2IObWhg',
#  'pUGyU-hxw5E',
#  '0VdzZQdaZ28',
#  'QCqrwlQ4EAQ',
#  'jAaJZLqryTI',
#  '5s_lGC2sxwQ',
#  'KmziL1djFkQ',
#  'p7CiFhiTdvY',
#  'BDi3SD7E6no',
#  'TWpIHI3Go_U',
#  '-qs7QocYUbQ',
#  'nfOCvysoTjA',
#  'EWKoWsAR1U4',
#  '0CEWNwXqKS4',
#  '4McKSuuUQ-0',
#  'Gvey20p3N5M',
#  'qTw0lYqTQSU',
#  'fHlJNjRRXWY',
#  'PjgLeP0G5Yw',
#  '4_9twnEduFA',
#  'H2r2N7D56Uw',
#  'PyblLBlpf0s',
#  '2BikxsbkuIU',
#  'E-WhAS6qzsU',
#  'OWEoIz5Kqfc',
#  'JLUqOmE9veI',
#  'n8Cp9XGzpow',
#  '1aGuhUFwvXA',
#  'vc1pJ8XdZa0',
#  'Y4xlUNfrvow',
#  '_gDOz7E6HVM',
#  '9dZJLWpGc7M',
#  'RJJugb2uJPs',
#  'PVY46hUp2EM',
#  'PKGSjLcz4G4',
#  'Olm-3FhJuGE',
#  'I-CIYnyAFzQ',
#  '9gG7f0HSjic',
#  'xfnRywBv5VM',
#  'UdsNBIzsmlI',
#  '2-DNswzCkqk',
#  'vpCRQjPX4YY',
#  'rN6OPfbGgcA',
#  'V5u_uVmaA1A',
#  '2jLNjOvHMto',
#  'iCbJcis7Ic0',
#  'wgB0--Q6klA',
#  'AdUZArA-kZw',
#  'i6xMBig-pP4',
#  'O98z3oiRc_k',
#  'QR1NHEr5N0g',
#  'sCecRPSQg6Y',
#  'IFmxwwqc8BM',
#  'r23q4EWU7U0',
#  'IMG98V6DPoU',
#  'xUP134NXEyE',
#  'i5_FhWloAa8',
#  'igA_m-DEVco',
#  'ucSuTR5qat8',
#  'iScueNcu3QM',
#  'Fc0XRcRmBP4',
#  'MImAiZIzzd4',
#  'pjIxDyLCOfQ',
#  'PBUtAdR1n6g',
#  'W4JwgcqpDBE',
#  'W0fPZQBFpVE',
#  '0EgSo7hsRWM',
#  '1OuRhD7FmTA',
#  'L0j7JkFmYDI',
#  'eDInXTA-jTg',
#  'ERww7FiLrqk',
#  'jmx1OZNMLr0',
#  '1uCH3zqbv2s',
#  'U_nugSKtbSk',
#  'vKeoXxVaga4',
#  'IRiJdLN-Ers',
#  'vA4r_MPRNsg',
#  '2EngAQX_kCg',
#  'QQrcd_62VWM',
#  'OFrLs22MDAw',
#  'x5ibe6pnuSg',
#  'IMG98V6DPoU',
#  'xUP134NXEyE',
#  'i5_FhWloAa8',
#  'igA_m-DEVco',
#  'ucSuTR5qat8',
#  'iScueNcu3QM',
#  'Fc0XRcRmBP4',
#  'MImAiZIzzd4',
#  'pjIxDyLCOfQ',
#  'PBUtAdR1n6g',
#  'W4JwgcqpDBE',
#  'W0fPZQBFpVE',
#  '0EgSo7hsRWM',
#  '1OuRhD7FmTA',
#  'L0j7JkFmYDI',
#  'eDInXTA-jTg',
#  'ERww7FiLrqk',
#  'jmx1OZNMLr0',
#  '1uCH3zqbv2s',
#  'U_nugSKtbSk',
#  'vKeoXxVaga4',
#  'IRiJdLN-Ers',
#  'vA4r_MPRNsg',
#  ...]

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
        part = 'snippet,statistics',
        id = ','.join(video_ids[i:i+50]))
        response = request.execute()
    
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                           published_date = video['snippet']['publishedAt'],
                           Views = video['statistics']['viewCount'],
                           Likes = video['statistics']['likeCount'],
                           Comments = video['statistics']['commentCount'])
            all_video_stats.append(video_stats)
      
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                   Title        published_date  \
# 0     Python Virtual Environments - Full Tutorial fo...  2024-03-16T14:47:21Z
# 1           Python Data Classes Are AMAZING! Here's Why  2024-03-13T15:20:48Z
# 2           Can ChatGPT Actually Teach You How To Code?  2024-03-10T14:00:37Z
# 3      Looking Into a REAL Codebase - Beyond the Basics  2024-03-07T14:00:23Z
# 4     Data Structures & Algorithms Roadmap - What Yo...  2024-03-03T14:00:15Z
# ...                                                 ...                   ...
# 999       Python Programming Tutorial #4 - IF/ELIF/ELSE  2017-06-12T18:00:04Z
# 1000        Python Programming Tutorial #3 - Conditions  2017-06-11T18:07:42Z
# 1001  Python Programming Tutorial #2 - Basic Operato...  2017-06-10T20:48:25Z
# 1002  Python Programming Tutorial #1 - Variables and...  2017-06-10T02:01:57Z
# 1003           A* Path Finding Algorithm(Visualization)  2017-06-09T02:36:24Z
#
#        Views Likes Comments
# 0      10886   767       30
# 1      24769   952       38
# 2      15146   611       64
# 3      20319   874       50
# 4      29509  1650       77
# ...      ...   ...      ...
# 999    69070  1750       64
# 1000   75769  1973       26
# 1001  108897  2440       66
# 1002  336795  5673      128
# 1003   25015   385       39
#
# [1004 rows x 5 columns]

# %%
video_data['published_date'] = pd.to_datetime(video_data['published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])
video_data
# Out:
#                                                   Title published_date  \
# 0     Python Virtual Environments - Full Tutorial fo...     2024-03-16
# 1           Python Data Classes Are AMAZING! Here's Why     2024-03-13
# 2           Can ChatGPT Actually Teach You How To Code?     2024-03-10
# 3      Looking Into a REAL Codebase - Beyond the Basics     2024-03-07
# 4     Data Structures & Algorithms Roadmap - What Yo...     2024-03-03
# ...                                                 ...            ...
# 999       Python Programming Tutorial #4 - IF/ELIF/ELSE     2017-06-12
# 1000        Python Programming Tutorial #3 - Conditions     2017-06-11
# 1001  Python Programming Tutorial #2 - Basic Operato...     2017-06-10
# 1002  Python Programming Tutorial #1 - Variables and...     2017-06-10
# 1003           A* Path Finding Algorithm(Visualization)     2017-06-09
#
#        Views  Likes  Comments
# 0      10886    767        30
# 1      24769    952        38
# 2      15146    611        64
# 3      20319    874        50
# 4      29509   1650        77
# ...      ...    ...       ...
# 999    69070   1750        64
# 1000   75769   1973        26
# 1001  108897   2440        66
# 1002  336795   5673       128
# 1003   25015    385        39
#
# [1004 rows x 5 columns]

# %%
top10_videos =  video_data.sort_values(by = 'Views', ascending = False)

# %%
top10_videos
# Out:
#                                                  Title published_date  \
# 669  12 Hour Coding Livestream - Creating an Online...     2019-10-18
# 598  Python Object Oriented Programming (OOP) - For...     2020-03-29
# 448  Python Website Full Tutorial - Flask, Authenti...     2021-02-01
# 384             5 Mini Python Projects - For Beginners     2021-06-10
# 709  Python Flappy Bird AI Tutorial (with NEAT) - C...     2019-08-10
# ..                                                 ...            ...
# 933            OBS Studio Tutorial - Best OBS Settings     2018-02-10
# 831                    techwithtim.net MY NEW WEBSITE!     2019-01-14
# 876          Channel Update - Big News & Announcements     2018-11-18
# 869                       5000 Subscribers - Thank You     2018-11-29
# 513                          Tech With Tim Live Stream     2020-09-16
#
#         Views   Likes  Comments
# 669  10819518  213267      3200
# 598   3206300   90080      2544
# 448   2712445   55726      2295
# 384   2705499   68209      1896
# 709   2357589   26103       353
# ..        ...     ...       ...
# 933      1321      55         6
# 831       797      48        15
# 876       612      31        15
# 869       432      28        21
# 513         0       0         0
#
# [1004 rows x 5 columns]

# %%
ax1 = sns.barplot(x = 'Views', y = 'Title', data = top10_videos)
# Out:
# C:\Users\Admin\anaconda3\envs\YT-env\lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Admin\anaconda3\envs\YT-env\lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from current font.
#   func(*args, **kwargs)
# Error in callback <function _draw_all_if_interactive at 0x00000169372B0B80> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axis.py:1388, in Axis.draw(self, renderer, *args, **kwargs)
#    1385 renderer.open_group(__name__, gid=self.get_gid())
#    1387 ticks_to_draw = self._update_ticks()
# -> 1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#    1391     tick.draw(renderer)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axis.py:1315, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axis.py:1315, in <listcomp>(.0)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:956, in Text.get_window_extent(self, renderer, dpi)
#     951     raise RuntimeError(
#     952         "Cannot get window extent of text w/o renderer. You likely "
#     953         "want to call 'figure.draw_without_rendering()' first.")
#     955 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 956     bbox, info, descent = self._get_layout(self._renderer)
#     957     x, y = self.get_unitless_position()
#     958     x, y = self.get_transform().transform((x, y))
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\backends\backend_agg.py:217, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     213     return super().get_text_width_height_descent(s, prop, ismath)
#     215 if ismath:
#     216     ox, oy, width, height, descent, font_image = \
# --> 217         self.mathtext_parser.parse(s, self.dpi, prop)
#     218     return width, height, descent
#     220 font = self._prepare_font(prop)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\mathtext.py:79, in MathTextParser.parse(self, s, dpi, prop, antialiased)
#      77 prop = prop.copy() if prop is not None else None
#      78 antialiased = mpl._val_or_rc(antialiased, 'text.antialiased')
# ---> 79 return self._parse_cached(s, dpi, prop, antialiased)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\mathtext.py:100, in MathTextParser._parse_cached(self, s, dpi, prop, antialiased)
#      97 if self._parser is None:  # Cache the parser globally.
#      98     self.__class__._parser = _mathtext.Parser()
# --> 100 box = self._parser.parse(s, fontset, fontsize, dpi)
#     101 output = _mathtext.ship(box)
#     102 if self._output_type == "vector":
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\_mathtext.py:2165, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2162     result = self._expression.parseString(s)
#    2163 except ParseBaseException as err:
#    2164     # explain becomes a plain method on pyparsing 3 (err.explain(0)).
# -> 2165     raise ValueError("\n" + ParseException.explain(err, 0)) from None
#    2166 self._state_stack = []
#    2167 self._in_subscript_or_superscript = False
#
# ValueError:
# How Much To Charge as a Freelance Developer ($ -$$$)
#                                                  ^
# ParseException: Expected end of text, found '$'  (at char 49), (line:1, col:50)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\YT-env\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axis.py:1388, in Axis.draw(self, renderer, *args, **kwargs)
#    1385 renderer.open_group(__name__, gid=self.get_gid())
#    1387 ticks_to_draw = self._update_ticks()
# -> 1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#    1391     tick.draw(renderer)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axis.py:1315, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\axis.py:1315, in <listcomp>(.0)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:956, in Text.get_window_extent(self, renderer, dpi)
#     951     raise RuntimeError(
#     952         "Cannot get window extent of text w/o renderer. You likely "
#     953         "want to call 'figure.draw_without_rendering()' first.")
#     955 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 956     bbox, info, descent = self._get_layout(self._renderer)
#     957     x, y = self.get_unitless_position()
#     958     x, y = self.get_transform().transform((x, y))
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\backends\backend_agg.py:217, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     213     return super().get_text_width_height_descent(s, prop, ismath)
#     215 if ismath:
#     216     ox, oy, width, height, descent, font_image = \
# --> 217         self.mathtext_parser.parse(s, self.dpi, prop)
#     218     return width, height, descent
#     220 font = self._prepare_font(prop)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\mathtext.py:79, in MathTextParser.parse(self, s, dpi, prop, antialiased)
#      77 prop = prop.copy() if prop is not None else None
#      78 antialiased = mpl._val_or_rc(antialiased, 'text.antialiased')
# ---> 79 return self._parse_cached(s, dpi, prop, antialiased)
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\mathtext.py:100, in MathTextParser._parse_cached(self, s, dpi, prop, antialiased)
#      97 if self._parser is None:  # Cache the parser globally.
#      98     self.__class__._parser = _mathtext.Parser()
# --> 100 box = self._parser.parse(s, fontset, fontsize, dpi)
#     101 output = _mathtext.ship(box)
#     102 if self._output_type == "vector":
#
# File ~\anaconda3\envs\YT-env\lib\site-packages\matplotlib\_mathtext.py:2165, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2162     result = self._expression.parseString(s)
#    2163 except ParseBaseException as err:
#    2164     # explain becomes a plain method on pyparsing 3 (err.explain(0)).
# -> 2165     raise ValueError("\n" + ParseException.explain(err, 0)) from None
#    2166 self._state_stack = []
#    2167 self._in_subscript_or_superscript = False
#
# ValueError:
# How Much To Charge as a Freelance Developer ($ -$$$)
#                                                  ^
# ParseException: Expected end of text, found '$'  (at char 49), (line:1, col:50)
